# %% [markdown]
# ## Fitting Random Forest Model - Primary

# %%
import pandas as pd

# %%
df = pd.read_csv('500hits.csv', encoding='latin-1')

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
df = df.drop(columns=['PLAYER','CS'])

# %%
X = df.iloc[:, 0:13]

# %%
y = df.iloc[:,13]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=17, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
rf.score(X_test, y_test)
# Out:
# 0.8279569892473119

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88        61
#            1       0.81      0.66      0.72        32
#
#     accuracy                           0.83        93
#    macro avg       0.82      0.79      0.80        93
# weighted avg       0.83      0.83      0.82        93

# %% [markdown]
# ## Feature Importance

# %%
features = pd.DataFrame(rf.feature_importances_, index=X.columns)

# %%
features
# Out:
#             0
# YRS  0.028384
# G    0.081405
# AB   0.090337
# R    0.117056
# H    0.154656
# 2B   0.055637
# 3B   0.047825
# HR   0.052809
# RBI  0.101347
# BB   0.041121
# SO   0.047303
# SB   0.047814
# BA   0.134306

# %% [markdown]
# ## Using Hyperparameters

# %%
rf2 = RandomForestClassifier(n_estimators=1000,
                            criterion='entropy',
                            min_samples_split=10,
                            max_depth=14,
                            random_state=42)

# %%
rf2.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=14, min_samples_split=10,
#                        n_estimators=1000, random_state=42)

# %%
rf2.score(X_test, y_test)
# Out:
# 0.8494623655913979

# %%
y_pred_2 = rf2.predict(X_test)

# %%
print(classification_report(y_test, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89        61
#            1       0.85      0.69      0.76        32
#
#     accuracy                           0.85        93
#    macro avg       0.85      0.81      0.82        93
# weighted avg       0.85      0.85      0.85        93

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### GridSearchCV

# %%
y.value_counts()
# Out:
# HOF
# 0    313
# 1    151
# 2      1
# Name: count, dtype: int64

# %%
y = y.replace(2,1)

# %% [markdown]
# #### Train _test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=17, test_size=0.2)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# %%
param_grid = {
    'n_estimators':[100,200],
    'criterion': ["gini", "entropy", "log_loss"],
    'max_depth':[None, 10, 20],
    'min_samples_split':[2,5],
    'min_samples_leaf': [1,2],
    'bootstrap': [True, False]
}

grid_search = GridSearchCV(RandomForestClassifier(),
                          param_grid, cv=skf)
grid_search.fit(X_train, y_train)
print('Best parameters:', grid_search.best_params_)
# Out:
# Best parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}

# %%
rand_search = RandomizedSearchCV(RandomForestClassifier(),
                          param_grid, cv=skf)
rand_search.fit(X_train, y_train)
print('Best parameters:', rand_search.best_params_)
# Out:
# Best parameters: {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': None, 'criterion': 'entropy', 'bootstrap': True}

# %%
best_rf = rand_search.best_estimator_

# %%
best_rf
# Out:
# RandomForestClassifier(criterion='entropy', min_samples_split=5)

# %%
best_rf.score(X_test, y_test)
# Out:
# 0.8172043010752689

# %%
y_pred_3 = best_rf.predict(X_test)

# %%
print(classification_report(y_test, y_pred_3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87        61
#            1       0.78      0.66      0.71        32
#
#     accuracy                           0.82        93
#    macro avg       0.81      0.78      0.79        93
# weighted avg       0.81      0.82      0.81        93

# %% [markdown]
# ### Feature Importances

# %%
importances = best_rf.feature_importances_
feature_names = X.columns 
forest_importances = pd.Series(importances, index=feature_names)
forest_importances.sort_values(ascending=False).plot.bar()
# Out:
# <Axes: >

# %%
import numpy as np
import shap
explainer = shap.TreeExplainer(best_rf)
shap_values = explainer.shap_values(X)
mean_abs_shap = np.abs(shap_values).mean(axis=0)

# %%
mean_abs_shap
# Out:
# array([[0.00625959, 0.00625959],
#        [0.02072298, 0.02072298],
#        [0.03263395, 0.03263395],
#        [0.08139735, 0.08139735],
#        [0.06954248, 0.06954248],
#        [0.01512458, 0.01512458],
#        [0.0207894 , 0.0207894 ],
#        [0.0190671 , 0.0190671 ],
#        [0.04642685, 0.04642685],
#        [0.0095855 , 0.0095855 ],
#        [0.0319957 , 0.0319957 ],
#        [0.01354367, 0.01354367],
#        [0.06122117, 0.06122117]])

# %%
shap_values = explainer(X)

# %%
shap_values
# Out:
# .values =
# array([[[-0.01080114,  0.01080114],
#         [-0.04480731,  0.04480731],
#         [-0.07915629,  0.07915629],
#         ...,
#         [-0.01723322,  0.01723322],
#         [ 0.00711417, -0.00711417],
#         [-0.12821975,  0.12821975]],
#
#        [[-0.0128765 ,  0.0128765 ],
#         [-0.02742284,  0.02742284],
#         [-0.05461271,  0.05461271],
#         ...,
#         [-0.01394432,  0.01394432],
#         [ 0.00207642, -0.00207642],
#         [-0.09264971,  0.09264971]],
#
#        [[-0.01269233,  0.01269233],
#         [-0.04402177,  0.04402177],
#         [-0.07924064,  0.07924064],
#         ...,
#         [-0.02471892,  0.02471892],
#         [ 0.00789959, -0.00789959],
#         [-0.13379202,  0.13379202]],
#
#        ...,
#
#        [[-0.00126926,  0.00126926],
#         [ 0.01473583, -0.01473583],
#         [ 0.03113096, -0.03113096],
#         ...,
#         [ 0.0420255 , -0.0420255 ],
#         [ 0.01033244, -0.01033244],
#         [ 0.04233159, -0.04233159]],
#
#        [[-0.0013514 ,  0.0013514 ],
#         [ 0.01636876, -0.01636876],
#         [ 0.01848129, -0.01848129],
#         ...,
#         [-0.00979597,  0.00979597],
#         [ 0.00755829, -0.00755829],
#         [ 0.02966583, -0.02966583]],
#
#        [[-0.00447088,  0.00447088],
#         [ 0.01511318, -0.01511318],
#         [ 0.02752195, -0.02752195],
#         ...,
#         [-0.01066379,  0.01066379],
#         [ 0.01726617, -0.01726617],
#         [ 0.01881778, -0.01881778]]], shape=(465, 13, 2))
#
# .base_values =
# array([[0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301],
#        [0.68045699, 0.31954301]])
#
# .data =
# array([[2.4000e+01, 3.0350e+03, 1.1434e+04, ..., 3.5700e+02, 8.9200e+02,
#         3.6600e-01],
#        [2.2000e+01, 3.0260e+03, 1.0972e+04, ..., 6.9600e+02, 7.8000e+01,
#         3.3100e-01],
#        [2.2000e+01, 2.7890e+03, 1.0195e+04, ..., 2.2000e+02, 4.3200e+02,
#         3.4500e-01],
#        ...,
#        [1.5000e+01, 1.8340e+03, 6.4990e+03, ..., 1.1900e+03, 3.1500e+02,
#         2.5600e-01],
#        [1.6000e+01, 1.8220e+03, 6.3090e+03, ..., 4.8900e+02, 7.4000e+01,
#         2.6300e-01],
#        [1.5000e+01, 1.4680e+03, 5.6290e+03, ..., 4.7100e+02, 2.6700e+02,
#         2.9500e-01]], shape=(465, 13))
