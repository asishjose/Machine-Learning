# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
book_sales = pd.read_csv('book_sales.csv',
                        index_col='Date',
                        parse_dates=['Date']).drop('Paperback', axis=1)

# %%
book_sales['Time'] = np.arange(len(book_sales.index))
book_sales['Lag_1'] = book_sales['Hardcover'].shift(1)
book_sales = book_sales.reindex(columns=['Hardcover', 'Time', 'Lag_1'])
book_sales.head()
# Out:
#             Hardcover  Time  Lag_1
# Date
# 2000-04-01        139     0    NaN
# 2000-04-02        128     1  139.0
# 2000-04-03        172     2  128.0
# 2000-04-04        139     3  172.0
# 2000-04-05        191     4  139.0

# %%
plt.figure(figsize=(12,4))
plt.plot(book_sales['Time'], book_sales['Hardcover'])
sns.regplot(x='Time', y='Hardcover', data=book_sales)
# Out:
# <Axes: xlabel='Time', ylabel='Hardcover'>
