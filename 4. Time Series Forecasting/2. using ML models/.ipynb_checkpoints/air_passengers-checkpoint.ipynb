# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('AirPassengers.csv')
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %% [markdown]
# ### Preprocessing

# %%
data = data.rename(columns={'Month':'Date'})

data['Month'] = [int(i.split('-')[1]) for i in data['Date']]
data['Year'] = [int(i.split('-')[0]) for i in data['Date']]

data['Series'] = np.arange(1, len(data)+1)

data.drop(['Date'], axis=1, inplace=True)
data = data[['Series', 'Year', 'Month', '#Passengers']]

data.head()
# Out:
#    Series  Year  Month  #Passengers
# 0       1  1949      1          112
# 1       2  1949      2          118
# 2       3  1949      3          132
# 3       4  1949      4          129
# 4       5  1949      5          121

# %% [markdown]
# ### Splitting

# %%
train = data[data['Year'] < 1960]
test = data[data['Year'] >= 1960]

train.shape, test.shape
# Out:
# ((132, 4), (12, 4))

# %%
from pycaret.regression import *

s = setup(data = train, 
          test_data = test, 
          target = '#Passengers', 
          fold_strategy= 'timeseries', 
          numeric_features= ['Year', 'Series'], 
          fold=3, 
          transform_target=True, 
          session_id=123,
          data_split_shuffle = False,
          fold_shuffle = False)
# Out:
# <style type="text/css">
# #T_45cda_row8_col1, #T_45cda_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_45cda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45cda_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_45cda_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45cda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_45cda_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_45cda_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45cda_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_45cda_row1_col1" class="data row1 col1" >#Passengers</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_45cda_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_45cda_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45cda_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_45cda_row3_col1" class="data row3 col1" >(144, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_45cda_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_45cda_row4_col1" class="data row4 col1" >(144, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_45cda_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_45cda_row5_col1" class="data row5 col1" >(132, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_45cda_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_45cda_row6_col1" class="data row6 col1" >(12, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_45cda_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_45cda_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_45cda_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_45cda_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_45cda_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_45cda_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_45cda_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_45cda_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_45cda_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_45cda_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_45cda_row12_col0" class="data row12 col0" >Transform target</td>
#       <td id="T_45cda_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_45cda_row13_col0" class="data row13 col0" >Transform target method</td>
#       <td id="T_45cda_row13_col1" class="data row13 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_45cda_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_45cda_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_45cda_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_45cda_row15_col1" class="data row15 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_45cda_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_45cda_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_45cda_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_45cda_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_45cda_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_45cda_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_45cda_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_45cda_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_45cda_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_45cda_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_45cda_row20_col1" class="data row20 col1" >0fdc</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(sort = 'MAE')
# Out:
# <style type="text/css">
# #T_2f352 th {
#   text-align: left;
# }
# #T_2f352_row0_col0, #T_2f352_row1_col0, #T_2f352_row1_col1, #T_2f352_row1_col2, #T_2f352_row1_col3, #T_2f352_row1_col4, #T_2f352_row1_col5, #T_2f352_row1_col6, #T_2f352_row2_col0, #T_2f352_row2_col1, #T_2f352_row2_col2, #T_2f352_row2_col3, #T_2f352_row2_col4, #T_2f352_row2_col5, #T_2f352_row2_col6, #T_2f352_row3_col0, #T_2f352_row3_col1, #T_2f352_row3_col2, #T_2f352_row3_col3, #T_2f352_row3_col4, #T_2f352_row3_col5, #T_2f352_row3_col6, #T_2f352_row4_col0, #T_2f352_row4_col1, #T_2f352_row4_col2, #T_2f352_row4_col3, #T_2f352_row4_col4, #T_2f352_row4_col5, #T_2f352_row4_col6, #T_2f352_row5_col0, #T_2f352_row5_col1, #T_2f352_row5_col2, #T_2f352_row5_col3, #T_2f352_row5_col4, #T_2f352_row5_col5, #T_2f352_row5_col6, #T_2f352_row6_col0, #T_2f352_row6_col1, #T_2f352_row6_col2, #T_2f352_row6_col3, #T_2f352_row6_col4, #T_2f352_row6_col5, #T_2f352_row6_col6, #T_2f352_row7_col0, #T_2f352_row7_col1, #T_2f352_row7_col2, #T_2f352_row7_col3, #T_2f352_row7_col4, #T_2f352_row7_col5, #T_2f352_row7_col6, #T_2f352_row8_col0, #T_2f352_row8_col1, #T_2f352_row8_col2, #T_2f352_row8_col3, #T_2f352_row8_col4, #T_2f352_row8_col5, #T_2f352_row8_col6, #T_2f352_row9_col0, #T_2f352_row9_col1, #T_2f352_row9_col2, #T_2f352_row9_col3, #T_2f352_row9_col4, #T_2f352_row9_col5, #T_2f352_row9_col6, #T_2f352_row10_col0, #T_2f352_row10_col1, #T_2f352_row10_col2, #T_2f352_row10_col3, #T_2f352_row10_col4, #T_2f352_row10_col5, #T_2f352_row10_col6, #T_2f352_row11_col0, #T_2f352_row11_col1, #T_2f352_row11_col2, #T_2f352_row11_col3, #T_2f352_row11_col4, #T_2f352_row11_col5, #T_2f352_row11_col6, #T_2f352_row12_col0, #T_2f352_row12_col1, #T_2f352_row12_col2, #T_2f352_row12_col3, #T_2f352_row12_col4, #T_2f352_row12_col5, #T_2f352_row12_col6, #T_2f352_row13_col0, #T_2f352_row13_col1, #T_2f352_row13_col2, #T_2f352_row13_col3, #T_2f352_row13_col4, #T_2f352_row13_col5, #T_2f352_row13_col6, #T_2f352_row14_col0, #T_2f352_row14_col1, #T_2f352_row14_col2, #T_2f352_row14_col3, #T_2f352_row14_col4, #T_2f352_row14_col5, #T_2f352_row14_col6, #T_2f352_row15_col0, #T_2f352_row15_col1, #T_2f352_row15_col2, #T_2f352_row15_col3, #T_2f352_row15_col4, #T_2f352_row15_col5, #T_2f352_row15_col6, #T_2f352_row16_col0, #T_2f352_row16_col1, #T_2f352_row16_col2, #T_2f352_row16_col3, #T_2f352_row16_col4, #T_2f352_row16_col5, #T_2f352_row16_col6, #T_2f352_row17_col0, #T_2f352_row17_col1, #T_2f352_row17_col2, #T_2f352_row17_col3, #T_2f352_row17_col4, #T_2f352_row17_col5, #T_2f352_row17_col6 {
#   text-align: left;
# }
# #T_2f352_row0_col1, #T_2f352_row0_col2, #T_2f352_row0_col3, #T_2f352_row0_col4, #T_2f352_row0_col5, #T_2f352_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2f352_row0_col7, #T_2f352_row1_col7, #T_2f352_row2_col7, #T_2f352_row3_col7, #T_2f352_row4_col7, #T_2f352_row5_col7, #T_2f352_row6_col7, #T_2f352_row7_col7, #T_2f352_row8_col7, #T_2f352_row9_col7, #T_2f352_row10_col7, #T_2f352_row11_col7, #T_2f352_row12_col7, #T_2f352_row13_col7, #T_2f352_row14_col7, #T_2f352_row15_col7, #T_2f352_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2f352_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2f352">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f352_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2f352_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2f352_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2f352_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2f352_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2f352_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2f352_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2f352_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f352_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_2f352_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_2f352_row0_col1" class="data row0 col1" >44.3192</td>
#       <td id="T_2f352_row0_col2" class="data row0 col2" >3050.6952</td>
#       <td id="T_2f352_row0_col3" class="data row0 col3" >53.8852</td>
#       <td id="T_2f352_row0_col4" class="data row0 col4" >-0.4522</td>
#       <td id="T_2f352_row0_col5" class="data row0 col5" >0.1714</td>
#       <td id="T_2f352_row0_col6" class="data row0 col6" >0.1521</td>
#       <td id="T_2f352_row0_col7" class="data row0 col7" >0.0433</td>
#     </tr>
#     <tr>
#       <th id="T_2f352_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_2f352_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_2f352_row1_col1" class="data row1 col1" >45.5643</td>
#       <td id="T_2f352_row1_col2" class="data row1 col2" >3233.7133</td>
#       <td id="T_2f352_row1_col3" class="data row1 col3" >55.6766</td>
#       <td id="T_2f352_row1_col4" class="data row1 col4" >-0.6553</td>
#       <td id="T_2f352_row1_col5" class="data row1 col5" >0.1765</td>
#       <td id="T_2f352_row1_col6" class="data row1 col6" >0.1576</td>
#       <td id="T_2f352_row1_col7" class="data row1 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_2f352_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_2f352_row2_col0" class="data row2 col0" >Linear Regression</td>
#       <td id="T_2f352_row2_col1" class="data row2 col1" >45.7431</td>
#       <td id="T_2f352_row2_col2" class="data row2 col2" >3261.7577</td>
#       <td id="T_2f352_row2_col3" class="data row2 col3" >55.8899</td>
#       <td id="T_2f352_row2_col4" class="data row2 col4" >-0.6723</td>
#       <td id="T_2f352_row2_col5" class="data row2 col5" >0.1771</td>
#       <td id="T_2f352_row2_col6" class="data row2 col6" >0.1583</td>
#       <td id="T_2f352_row2_col7" class="data row2 col7" >3.1033</td>
#     </tr>
#     <tr>
#       <th id="T_2f352_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_2f352_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_2f352_row3_col1" class="data row3 col1" >45.7835</td>
#       <td id="T_2f352_row3_col2" class="data row3 col2" >3257.2206</td>
#       <td id="T_2f352_row3_col3" class="data row3 col3" >55.8542</td>
#       <td id="T_2f352_row3_col4" class="data row3 col4" >-0.6687</td>
#       <td id="T_2f352_row3_col5" class="data row3 col5" >0.1770</td>
#       <td id="T_2f352_row3_col6" class="data row3 col6" >0.1585</td>
#       <td id="T_2f352_row3_col7" class="data row3 col7" >0.0433</td>
#     </tr>
#     <tr>
#       <th id="T_2f352_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_2f352_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_2f352_row4_col1" class="data row4 col1" >45.8053</td>
#       <td id="T_2f352_row4_col2" class="data row4 col2" >3260.6009</td>
#       <td id="T_2f352_row4_col3" class="data row4 col3" >55.8841</td>
#       <td id="T_2f352_row4_col4" class="data row4 col4" >-0.6721</td>
#       <td id="T_2f352_row4_col5" class="data row4 col5" >0.1771</td>
#       <td id="T_2f352_row4_col6" class="data row4 col6" >0.1586</td>
#       <td id="T_2f352_row4_col7" class="data row4 col7" >0.0467</td>
#     </tr>
#     <tr>
#       <th id="T_2f352_level0_row5" class="row_heading level0 row5" >huber</th>
#       <td id="T_2f352_row5_col0" class="data row5 col0" >Huber Regressor</td>
#       <td id="T_2f352_row5_col1" class="data row5 col1" >46.0420</td>
#       <td id="T_2f352_row5_col2" class="data row5 col2" >3308.9723</td>
#       <td id="T_2f352_row5_col3" class="data row5 col3" >56.4600</td>
#       <td id="T_2f352_row5_col4" class="data row5 col4" >-0.8186</td>
#       <td id="T_2f352_row5_col5" class="data row5 col5" >0.1802</td>
#       <td id="T_2f352_row5_col6" class="data row5 col6" >0.1618</td>
#       <td id="T_2f352_row5_col7" class="data row5 col7" >0.0533</td>
#     </tr>
#     <tr>
#       <th id="T_2f352_leve

# %%
future_dates = pd.date_range(start = '1961-01-01', end = '1965-01-01', freq = 'MS')
future_df = pd.DataFrame()
future_df['Month'] = [i.month for i in future_dates]
future_df['Year'] = [i.year for i in future_dates]
future_df['Series'] = np.arange(145, (145+len(future_dates)))
future_df.head()
# Out:
#    Month  Year  Series
# 0      1  1961     145
# 1      2  1961     146
# 2      3  1961     147
# 3      4  1961     148
# 4      5  1961     149

# %%
predictions_future = predict_model(best, data=future_df)
predictions_future.head()
# Out:
#    Month  Year  Series  prediction_label
# 0      1  1961     145        524.718637
# 1      2  1961     146        529.610707
# 2      3  1961     147        534.542524
# 3      4  1961     148        539.514364
# 4      5  1961     149        544.526504

# %%
data.plot()
# Out:
# <Axes: >

# %%
predictions_future.plot()
# Out:
# <Axes: >
